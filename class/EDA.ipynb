# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
from IPython.display import HTML

# %%
df = pd.read_csv('D:\GitRepo\Blog\class\data.csv', sep=';')
df.isnull().sum().sum()
# no need to clean the database

df["diagnosis"] = df["diagnosis"].replace("M", 1)
df["diagnosis"] = df["diagnosis"].replace("B", 0)
df.head()

# %%
df['diagnosis'].describe()

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="diagnosis", data=df, hue="diagnosis").set_title('Bar count diagnosis')

# %%
f, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(df.corr(), annot = True, fmt='.1g', cbar=False)
# Out:
# <AxesSubplot:>

# %%
radius_mean
perimeter_mean	area_mean	
concavity_mean
radius_worst
perimeter_worst	area_worst
concavity_worst	concave points_worst

# %%
sns.distplot( df["radius_mean"] , color="skyblue")
# Out:
# <AxesSubplot:xlabel='radius_mean', ylabel='Density'>

# %%
sns.distplot( df["concavity_mean"] , color="olive")
# Out:
# <AxesSubplot:xlabel='concavity_mean', ylabel='Density'>

# %%
sns.distplot( df["perimeter_mean"] , color="gold")
# Out:
# <AxesSubplot:xlabel='perimeter_mean', ylabel='Density'>

# %%
sns.distplot( df["area_mean"] , color="teal")
# Out:
# <AxesSubplot:xlabel='area_mean', ylabel='Density'>

# %%
plt.figure(figsize=(12, 5))
ax = plt.subplot(1,3,1)
sns.boxplot(y="concavity_worst", x="diagnosis", data=df).set_title("Price by city zone")
sns.stripplot(y="concavity_worst", x="diagnosis", data=df,jitter=True, marker='o',alpha=0.3,color="black")
plt.ylabel('diagnosis', multialignment='center')
plt.title('concavity_mean')
ax = plt.subplot(1,3,2)
sns.boxplot(y="perimeter_worst", x="diagnosis", data=df).set_title("Price by city zone")
sns.stripplot(y="perimeter_worst", x="diagnosis", data=df,jitter=True, marker='o',alpha=0.3,color="black")
plt.ylabel('diagnosis', multialignment='center')
plt.title('perimeter_mean')
ax = plt.subplot(1,3,3)
sns.boxplot(y='smoothness_mean', x="diagnosis", data=df).set_title("Price by city zone")
sns.stripplot(y="smoothness_mean", x="diagnosis", data=df,jitter=True, marker='o',alpha=0.3,color="black")
plt.ylabel('diagnosis', multialignment='center')
plt.title('smoothness_mean')
# Out:
# Text(0.5, 1.0, 'smoothness_mean')
